# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# The Sparks Foundation
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:white;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Graduate Rotational Internship Program
# </p>
# </div>

# %% [markdown]
# <a id="1.1"></a>
# <h2 style="font-family: Verdana; font-size: 15px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>Submitted By-> </b>Upasana Dhami </h2>
# <a id="1.1"></a>
# <h2 style="font-family: Verdana; font-size: 15px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>Role-> </b>Data Science & Business Analytics Tasks </h2>
# <a id="1.1"></a>
# <h2 style="font-family: Verdana; font-size: 15px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>Task 2-> </b>From the given ‘Iris’ dataset, predict the optimum number of clusters
# and represent it visually. </h2>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1.1"></a>
# <h2 style="font-family: Verdana; font-size: 28px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>Objective </b></h2>

# %% [markdown]
# <div style="font-family:Verdana; background-color:aliceblue; padding:30px; font-size:17px;color:#034914">
#
# 💡 The objective of this Assignment is to Predict the optimum number of clusters.<br>
# 💡 The second objective of this Assignment is to Visualize the clusters formed.
# 💡 In this assignment we will do clustering using K-Means Clustering.<br>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set(style="darkgrid",font_scale=1.5)

from sklearn import datasets
from sklearn.cluster import KMeans

# %% [markdown]
# ## Loading Dataset

# %%
df = datasets.load_iris()

# %%
df = pd.DataFrame(df.data, columns = df.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ---

# %% [markdown]
# ## Findinging the optimum number of clusters for k-means classification

# %%
x = df.iloc[:, [0, 1, 2, 3]].values

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# ## Plotting the results onto a line graph, allowing us to observe 'The elbow'

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1, 11), wcss)
plt.title('The elbow method',fontweight="black",size=20,pad=15)
plt.xlabel('Number of clusters')
plt.xticks(list(range(0,11)))
plt.ylabel('WCSS') 
plt.show()

# %% [markdown]
# <div style="font-family:Verdana; background-color:aliceblue; padding:30px; font-size:17px;color:#034914">
#
# <b>Observation</b><br>
#
# 💡 We can clearly see from the above graph that the optimum clusters is where the elbow occurs.<br>
# 💡 This is when the within cluster sum of squares (WCSS) doesn't decrease significantly with every iteration.<br>
# 💡 So can make an insight that the total number of clusters will be <b>3</b><br>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## Creating thee K-Means Clustering Model.

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# ## Visualizing the Clusters Formed.

# %%
plt.figure(figsize=(16,6))
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 200, c = 'black', label = 'Centroids')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="font-family:Verdana; background-color:aliceblue; padding:30px; font-size:17px;color:#034914">
#
# <b>Conclusion</b><br>
#
# 💡 We have used K-Means Clustering Algorithm for clustering the different species of iris flower.<br>
# 💡 We have used "The Elbow Method" for finfing the total number of clusters that can be formed. In result we got total number of clusters as 3 and we already know that there are total 3 different species.<br>
# 💡 We have used scatterplot & K-Means to visualize the different clusters formed.<br>
# </div>
